# %%
# !pip install -q nicHelper
# !pip install -q -U PyYAML
# Out:
# ERROR: Cannot uninstall 'PyYAML'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
import yaml, json
from nicHelper.schema import validateUrl

# %%
# response
branch='productmaster'
url = f'https://raw.githubusercontent.com/thanakijwanavit/villaMasterSchema/{branch}/productmaster/productmaster.yaml'
exampleData = {'cprcode': 36679,
  'iprcode': 36679,
  'oprcode': 36679,
  'ordertype': 'Y',
  'pr_abb': 'LA COOKIES SMALL100G',
  'pr_active': True,
  'pr_cgcode': '01',
  'pr_code': '0036679',
  'pr_dpcode': '18',
  'pr_engname': 'LA COOKIES BAG SMALL 100 G.',
  'pr_ggcode': '006',
  'pr_market': 'แอลเอคุกกี้ถุงเล็ก100ก.',
  'pr_name': 'แอลเอ คุกกี้ถุงเล็ก 100 ก.',
  'pr_puqty': '1.00',
  'pr_sa_method': '1',
  'pr_sucode1': 'F106',
  'pr_suref3': 'A',
  'prtype': 'I',
  'psqty': 1,
  'pstype': '1',
  'pr_country_th': '',
  'pr_country_en': '',
  'pr_keyword_th': 'เบเกอรี่',
  'pr_keyword_en': 'Bakery',
  'pr_filter_th': 'Bakery  Snacks,Fresh',
  'pr_filter_en': 'Bakery  Snacks,Fresh',
  'online_category_l1_th': 'อาหารสด',
  'online_category_l1_en': 'Bakery',
  'online_category_l2_th': 'เบเกอรี่ และ แสน็ค',
  'online_category_l2_en': 'Cakes & Pastries',
  'online_category_l3_th': '',
  'online_category_l3_en': '',
  'villa_category_l1_en': 'Fresh',
  'villa_category_l2_en': 'Fresh Produce',
  'villa_category_l3_en': 'Bakery',
  'villa_category_l4_en': 'Cookie and confectionery',
  'content_en': '0036679 0036679 La Bakery Cookies (s) 100gm Bakery 0036679-20366797       Bakery',
  'content_th': 'แอลเอ คุกกี้ถุงเล็ก 100 ก.  เบเกอรี่ LA COOKIES SMALL100G แอลเอคุกกี้ถุงเล็ก100ก.',
  'hema_brand_th': '',
  'hema_brand_en': '',
  'hema_sizedesc': '',
  'pr_brand_en': 'L.A. Bakery',
  'pr_brand_th': 'L.A. Bakery',
  'pr_online_name_en': 'La Bakery Cookies (s) 100gm',
  'pr_online_name_th': 'แอลเอ คุกกี้ถุงเล็ก 100 ก.',
  'hema_name_en': 'La Bakery Cookies (s) 100gm',
  'hema_name_th': 'แอลเอ คุกกี้ถุงเล็ก 100 ก.',
  'pr_name_en': 'LA COOKIES BAG SMALL 100 G.',
  'pr_name_th': 'แอลเอ คุกกี้ถุงเล็ก 100 ก.',
  'pr_barcode': '20366797',
  'pr_barcode2': '2036679',
  'sort_weight': 0,
  'master_online': True,
  'salemode_unit': 'ITEM',
  'ba_nprice': 35.00,
  'sort_villa_sku': 0}
    
from nicHelper.schema import validateUrl
validateUrl(url, input_=exampleData, format_ = 'yaml')
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-9-a7a54a830ede> in <module>
#      60
#      61 from nicHelper.schema import validateUrl
# ---> 62 validateUrl(url, input_=exampleData, format_ = 'yaml')
#
# ~/opt/miniconda3/envs/python38/lib/python3.8/site-packages/nicHelper/schema.py in validateUrl(url, input_, format_)
#      17     print('invalid schema format, using json')
#      18     schema = requests.get(url).json()
# ---> 19   res = jsonschema.validate(input_,schema)
#      20   return SimpleNamespace(**input_)
#
# ~/opt/miniconda3/envs/python38/lib/python3.8/site-packages/jsonschema/validators.py in validate(instance, schema, cls, *args, **kwargs)
#     932     error = exceptions.best_match(validator.iter_errors(instance))
#     933     if error is not None:
# --> 934         raise error
#     935
#     936
#
# ...

# %%
from nicHelper.dictUtil import genSchema
print(genSchema(exampleData, format_='yaml'))

# %%
branch='master'
url = f'https://raw.githubusercontent.com/thanakijwanavit/villaMasterSchema/{branch}/images/fileNames.yaml'
exampleData = {
    'iprcode': 12332425,
    'cprcode': 12321342134,
    # 'djsflkdsjflk': 'kfadjslkfjlk',
    '123':'123'
}
from nicHelper.dictUtil import genSchema
print(genSchema(exampleData, format_='yaml'))

# %%
url = "https://raw.githubusercontent.com/thanakijwanavit/villaMasterSchema/products/product/product.yaml"
validateUrl(url, input_=exampleData, format_='yaml')

# %%
memberFunctionLog = {'cprcode': 36679,
  'iprcode': 36679,
  'oprcode': 36679,
  'ordertype': 'Y',
  'pr_abb': 'LA COOKIES SMALL100G',
  'pr_active': 'Y',
  'pr_cgcode': '01',
  'pr_code': '0036679',
  'pr_dpcode': '18',
  'pr_engname': 'LA COOKIES BAG SMALL 100 G.',
  'pr_ggcode': '006',
  'pr_market': 'แอลเอคุกกี้ถุงเล็ก100ก.',
  'pr_name': 'แอลเอ คุกกี้ถุงเล็ก 100 ก.',
  'pr_puqty': '1.00',
  'pr_sa_method': '1',
  'pr_sucode1': 'F106',
  'pr_suref3': 'A',
  'prtype': 'I',
  'psqty': '1',
  'pstype': '1',
  'pr_country_th': '',
  'pr_country_en': '',
  'pr_keyword_th': 'เบเกอรี่',
  'pr_keyword_en': 'Bakery',
  'pr_filter_th': 'Bakery  Snacks,Fresh',
  'pr_filter_en': 'Bakery  Snacks,Fresh',
  'online_category_l1_th': 'อาหารสด',
  'online_category_l1_en': 'Bakery',
  'online_category_l2_th': 'เบเกอรี่ และ แสน็ค',
  'online_category_l2_en': 'Cakes & Pastries',
  'online_category_l3_th': '',
  'online_category_l3_en': '',
  'villa_category_l1_en': 'Fresh',
  'villa_category_l2_en': 'Fresh Produce',
  'villa_category_l3_en': 'Bakery',
  'villa_category_l4_en': 'Cookie and confectionery',
  'content_en': '0036679 0036679 La Bakery Cookies (s) 100gm Bakery 0036679-20366797       Bakery',
  'content_th': 'แอลเอ คุกกี้ถุงเล็ก 100 ก.  เบเกอรี่ LA COOKIES SMALL100G แอลเอคุกกี้ถุงเล็ก100ก.',
  'hema_brand_th': '',
  'hema_brand_en': '',
  'hema_sizedesc': '',
  'pr_brand_en': 'L.A. Bakery',
  'pr_brand_th': 'L.A. Bakery',
  'pr_online_name_en': 'La Bakery Cookies (s) 100gm',
  'pr_online_name_th': 'แอลเอ คุกกี้ถุงเล็ก 100 ก.',
  'hema_name_en': 'La Bakery Cookies (s) 100gm',
  'hema_name_th': 'แอลเอ คุกกี้ถุงเล็ก 100 ก.',
  'pr_name_en': 'LA COOKIES BAG SMALL 100 G.',
  'pr_name_th': 'แอลเอ คุกกี้ถุงเล็ก 100 ก.',
  'pr_barcode': 20366797,
  'pr_barcode2': 2036679,
  'sort_weight': '0',
  'master_online': 'Y',
  'SaleMode_unit': 'ITEM',
  'ba_nprice': '35.00',
  'sort_villa_sku': 0,
                    'test':'test'}
from nicHelper.dictUtil import genSchema
print(genSchema(memberFunctionLog, format_='yaml'))
# Out:
# $schema: http://json-schema.org/schema#
# properties:
#   SaleMode_unit:
#     type: string
#   ba_nprice:
#     type: string
#   content_en:
#     type: string
#   content_th:
#     type: string
#   cprcode:
#     type: integer
#   hema_brand_en:
#     type: string
#   hema_brand_th:
#     type: string
#   hema_name_en:
#     type: string
#   hema_name_th:
#     type: string
#   hema_sizedesc:
#     type: string
#   iprcode:
#     type: integer
#   master_online:
#     type: string
#   online_category_l1_en:
#     type: string
#   online_category_l1_th:
#     type: string
#   online_category_l2_en:
#     type: string
#   online_category_l2_th:
#     type: string
#   online_category_l3_en:
#     type: string
#   online_category_l3_th:
#     type: string
#   oprcode:
#     type: integer
#   ordertype:
#     type: string
#   pr_abb:
#     type: string
#   pr_active:
#     type: string
#   pr_barcode:
#     type: integer
#   pr_barcode2:
#     type: integer
#   pr_brand_en:
# ...

# %%
url = "https://raw.githubusercontent.com/thanakijwanavit/villaMasterSchema/productmaster/productmaster/productmaster.yaml"
validateUrl(url, input_=memberFunctionLog, format_='yaml')
# Out:
# namespace(SaleMode_unit='ITEM', ba_nprice='35.00', content_en='0036679 0036679 La Bakery Cookies (s) 100gm Bakery 0036679-20366797       Bakery', content_th='แอลเอ คุกกี้ถุงเล็ก 100 ก.  เบเกอรี่ LA COOKIES SMALL100G แอลเอคุกกี้ถุงเล็ก100ก.', cprcode=36679, hema_brand_en='', hema_brand_th='', hema_name_en='La Bakery Cookies (s) 100gm', hema_name_th='แอลเอ คุกกี้ถุงเล็ก 100 ก.', hema_sizedesc='', iprcode=36679, master_online='Y', online_category_l1_en='Bakery', online_category_l1_th='อาหารสด', online_category_l2_en='Cakes & Pastries', online_category_l2_th='เบเกอรี่ และ แสน็ค', online_category_l3_en='', online_category_l3_th='', oprcode=36679, ordertype='Y', pr_abb='LA COOKIES SMALL100G', pr_active='Y', pr_barcode=20366797, pr_barcode2=2036679, pr_brand_en='L.A. Bakery', pr_brand_th='L.A. Bakery', pr_cgcode='01', pr_code='0036679', pr_country_en='', pr_country_th='', pr_dpcode='18', pr_engname='LA COOKIES BAG SMALL 100 G.', pr_filter_en='Bakery  Snacks,Fresh', pr_filter_th='Bakery  Sna
# ...
